# %%
from huggingface_hub import login
from dotenv import load_dotenv
import os

load_dotenv()

hf_token = os.getenv("HUGGINGFACE_TOKEN")

if hf_token:
    print("Токен Hugging Face успешно загружен из .env файла.")
    login(token=hf_token)
else:
    print("ВНИМАНИЕ: Токен Hugging Face не найден в .env файле.")
    print("Пожалуйста, создайте файл .env в корне проекта и добавьте в него HUGGINGFACE_TOKEN.")
# Out:
# Токен Hugging Face успешно загружен из .env файла.

# %%
import pandas as pd
import ast
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("xlm-roberta-base")

# %%
def _tokenize_and_filter(text: str) -> tuple[list[str], list[tuple[int, int]]]:
    if tokenizer is None:
        raise RuntimeError("Токенизатор не был инициализирован.")
    encoding = tokenizer(text, return_offsets_mapping=True)
    tokens = tokenizer.convert_ids_to_tokens(encoding["input_ids"])
    offsets = encoding["offset_mapping"]
    filtered_tokens, filtered_offsets = [], []
    for token, offset in zip(tokens, offsets):
        if offset != (0, 0):
            filtered_tokens.append(token)
            filtered_offsets.append(offset)
    return filtered_tokens, filtered_offsets

# %%
def indices_to_bio(text: str, annotations: list) -> tuple[list[str], list[str]]:
    if tokenizer is None:
        raise RuntimeError("Токенизатор не был инициализирован.")

    encoding = tokenizer(text, return_offsets_mapping=True)
    tokens = tokenizer.convert_ids_to_tokens(encoding["input_ids"])
    offsets = encoding["offset_mapping"]

    filtered_tokens = []
    filtered_offsets = []
    for token, offset in zip(tokens, offsets):
        if offset != (0, 0):
            filtered_tokens.append(token)
            filtered_offsets.append(offset)

    bio_tags = ["O"] * len(filtered_tokens)

    annotations_sorted = sorted(annotations, key=lambda x: x[0])

    last_assigned_idx = -1
    last_core = None

    for ann_start, ann_end, ann_label in annotations_sorted:
        if ann_label == "O":
            continue

        core = ann_label.split("-", 1)[-1]
        ann_is_I = ann_label.startswith("I-")

        overlapping_idxs = [
            i for i, (ts, te) in enumerate(filtered_offsets)
            if max(ts, ann_start) < min(te, ann_end)
        ]
        if not overlapping_idxs:
            continue

        for j, tok_idx in enumerate(overlapping_idxs):
            if j == 0:
                if ann_is_I:
                    if last_assigned_idx == tok_idx - 1 and last_core == core:
                        bio_tags[tok_idx] = f"I-{core}"
                    else:
                        bio_tags[tok_idx] = f"B-{core}"
                else:
                    bio_tags[tok_idx] = f"B-{core}"
            else:
                bio_tags[tok_idx] = f"I-{core}"

            last_assigned_idx = tok_idx
            last_core = core

    return filtered_tokens, bio_tags

# %%
def bio_to_indices(text: str, bio_tags: list) -> list:
    if tokenizer is None:
        raise RuntimeError("Токенизатор не был инициализирован.")

    encoding = tokenizer(text, return_offsets_mapping=True)
    offsets = encoding["offset_mapping"]

    filtered_offsets = [offset for offset in offsets if offset != (0, 0)]

    if len(bio_tags) != len(filtered_offsets):
        raise ValueError("Количество BIO-тегов не совпадает с количеством отфильтрованных токенов")

    annotations = []
    current_entity_indices = []

    extended_tags = bio_tags + ["O"]

    for i, tag in enumerate(extended_tags):
        if tag.startswith("B-"):
            if current_entity_indices:
                start_token_idx = current_entity_indices[0]
                end_token_idx = current_entity_indices[-1]
                start_char = filtered_offsets[start_token_idx][0]
                end_char = filtered_offsets[end_token_idx][1]
                entity_tag = bio_tags[start_token_idx]
                annotations.append((start_char, end_char, entity_tag))

            current_entity_indices = [i]

        elif tag.startswith("I-"):
            if current_entity_indices:
                prev_tag = bio_tags[i - 1]
                if prev_tag != "O" and prev_tag.split("-")[-1] == tag.split("-")[-1]:
                    current_entity_indices.append(i)
                else:
                    if current_entity_indices:
                        start_token_idx = current_entity_indices[0]
                        end_token_idx = current_entity_indices[-1]
                        start_char = filtered_offsets[start_token_idx][0]
                        end_char = filtered_offsets[end_token_idx][1]
                        entity_tag = bio_tags[start_token_idx]
                        annotations.append((start_char, end_char, entity_tag))
                    current_entity_indices = [i]
            else:
                current_entity_indices = [i]

        else:
            if current_entity_indices:
                start_token_idx = current_entity_indices[0]
                end_token_idx = current_entity_indices[-1]
                start_char = filtered_offsets[start_token_idx][0]
                end_char = filtered_offsets[end_token_idx][1]
                entity_tag = bio_tags[start_token_idx]
                annotations.append((start_char, end_char, entity_tag))

            current_entity_indices = []

    return annotations

# %%
def sanitize_annotations(text: str, annotations: list) -> tuple[str, list]:
    new_annotations = []
    for start, end, label in annotations:
        entity_text = text[start:end]
        stripped_entity_text_right = entity_text.rstrip()
        new_end = start + len(stripped_entity_text_right)
        stripped_entity_text_left = stripped_entity_text_right.lstrip()
        new_start = new_end - len(stripped_entity_text_left)
        if new_start < new_end:
            new_annotations.append((new_start, new_end, label))
    return text, new_annotations

# %%
try:
    df_train = pd.read_csv("../../data/raw/train.csv", sep=";")
    df_train["annotation"] = df_train["annotation"].apply(ast.literal_eval)
    print("Данные для проведения теста успешно загружены.")
except FileNotFoundError:
    print("Критическая ошибка: файл train.csv не найден. Проверьте путь '../../data/raw/train.csv'.")

sample_df = df_train.sample(n=min(1000, len(df_train)), random_state=42)
errors_found = 0
total_checked = 0

print(f"Запуск кругового теста на {len(sample_df)} случайных примерах с предварительной очисткой...")

for _, row in sample_df.iterrows():
    total_checked += 1
    original_text = row["sample"]
    original_annotations = row["annotation"]

    try:
        sanitized_text, sanitized_annotations = sanitize_annotations(original_text, original_annotations)

        sanitized_annotations_no_O = [ann for ann in sanitized_annotations if ann[2] != "O"]

        tokens, bio_tags = indices_to_bio(sanitized_text, sanitized_annotations)
        reconstructed_annotations = bio_to_indices(sanitized_text, bio_tags)

        if sorted(sanitized_annotations_no_O, key=lambda x: x[0]) != sorted(reconstructed_annotations,
                                                                            key=lambda x: x[0]):
            errors_found += 1
            print("-" * 80)
            print(f"ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: '{original_text}'")
            print(f"  Эталон (без 'O'): {sorted(sanitized_annotations_no_O, key=lambda x: x[0])}")
            print(f"  Восстановлено:    {sorted(reconstructed_annotations, key=lambda x: x[0])}")
            print(f"  (Промежуточные BIO-теги: {bio_tags})")
            print("-" * 80)

    except Exception as e:
        errors_found += 1
        print(f"КРИТИЧЕСКАЯ ОШИБКА ИСПОЛНЕНИЯ в примере '{original_text}': {e}")
        import traceback

        traceback.print_exc()

print("\n" + "=" * 40)
if errors_found == 0:
    print(f"РЕЗУЛЬТАТ: УСПЕХ. Круговой тест пройден на {total_checked} примерах без расхождений.")
else:
    print(f"РЕЗУЛЬТАТ: ПРОВАЛ. Обнаружено {errors_found} ошибок на {total_checked} примерах.")
print("=" * 40)
# Out:
# Данные для проведения теста успешно загружены.
# Запуск кругового теста на 1000 случайных примерах с предварительной очисткой...
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'кабачковая икра'
#   Эталон (без 'O'): [(0, 10, 'B-TYPE'), (11, 15, 'I-TYPE')]
#   Восстановлено:    [(0, 15, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'ядра подсолнечника'
#   Эталон (без 'O'): [(0, 4, 'B-TYPE'), (5, 18, 'I-TYPE')]
#   Восстановлено:    [(0, 18, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'хлопья кукурузные'
#   Эталон (без 'O'): [(0, 6, 'B-TYPE'), (7, 17, 'I-TYPE')]
#   Восстановлено:    [(0, 17, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'пудра сахарная'
#   Эталон (без 'O'): [(0, 5, 'B-TYPE'), (6, 14, 'I-TYPE')]
#   Восстановлено:    [(0, 14, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'люстры, светильники'
#   Эталон (без 'O'): [(0, 7, 'B-TYPE'), (8, 19, 'I-TYPE')]
#   Восстановлено:    [(0, 19, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'сырок суфле'
#   Эталон (без 'O'): [(0, 5, 'B-TYPE'), (6, 11, 'I-TYPE')]
#   Восстановлено:    [(0, 11, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'вода питьевая нег'
#   Эталон (без 'O'): [(0, 4, 'B-TYPE'), (5, 13, 'I-TYPE')]
#   Восстановлено:    [(0, 13, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'O', 'O'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'хлеб вкус и польза'
#   Эталон (без 'O'): [(0, 4, 'B-TYPE'), (5, 9, 'B-BRAND'), (10, 11, 'I-BRAND'), (12, 18, 'I-BRAND')]
#   Восстановлено:    [(0, 4, 'B-TYPE'), (5, 18, 'B-BRAND')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'B-BRAND', 'I-BRAND', 'I-BRAND', 'I-BRAND'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'декоративная космети'
#   Эталон (без 'O'): [(0, 12, 'B-TYPE'), (13, 20, 'I-TYPE')]
#   Восстановлено:    [(0, 20, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'напиток газированный со вкусом саперави'
#   Эталон (без 'O'): [(0, 7, 'B-TYPE'), (8, 20, 'I-TYPE')]
#   Восстановлено:    [(0, 20, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'O', 'O', 'O', 'O', 'O', 'O'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'детское молоко'
#   Эталон (без 'O'): [(0, 7, 'B-TYPE'), (8, 14, 'I-TYPE')]
#   Восстановлено:    [(0, 14, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'сахар ваниль'
#   Эталон (без 'O'): [(0, 5, 'B-TYPE'), (6, 12, 'I-TYPE')]
#   Восстановлено:    [(0, 12, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'яблочный уксус'
#   Эталон (без 'O'): [(0, 8, 'B-TYPE'), (9, 14, 'I-TYPE')]
#   Восстановлено:    [(0, 14, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'ребра свинные'
#   Эталон (без 'O'): [(0, 5, 'B-TYPE'), (6, 13, 'I-TYPE')]
#   Восстановлено:    [(0, 13, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'зелень асорти'
#   Эталон (без 'O'): [(0, 6, 'B-TYPE'), (7, 13, 'I-TYPE')]
#   Восстановлено:    [(0, 13, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'вторые блюда'
#   Эталон (без 'O'): [(0, 6, 'B-TYPE'), (7, 12, 'I-TYPE')]
#   Восстановлено:    [(0, 12, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'сок персиковый'
#   Эталон (без 'O'): [(0, 3, 'B-TYPE'), (4, 14, 'I-TYPE')]
#   Восстановлено:    [(0, 14, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'рис агро альянс'
#   Эталон (без 'O'): [(0, 3, 'B-TYPE'), (4, 8, 'B-BRAND'), (9, 15, 'I-BRAND')]
#   Восстановлено:    [(0, 3, 'B-TYPE'), (4, 15, 'B-BRAND')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'B-BRAND', 'I-BRAND'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'корм паучи для собак'
#   Эталон (без 'O'): [(0, 4, 'B-TYPE'), (5, 10, 'I-TYPE')]
#   Восстановлено:    [(0, 10, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'O', 'O'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'сыр рассольный'
#   Эталон (без 'O'): [(0, 3, 'B-TYPE'), (4, 14, 'I-TYPE')]
#   Восстановлено:    [(0, 14, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'патока крахмальная'
#   Эталон (без 'O'): [(0, 6, 'B-TYPE'), (7, 18, 'I-TYPE')]
#   Восстановлено:    [(0, 18, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'бритвы, триммеры'
#   Эталон (без 'O'): [(0, 7, 'B-TYPE'), (8, 16, 'I-TYPE')]
#   Восстановлено:    [(0, 16, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'замороженные фрукты'
#   Эталон (без 'O'): [(0, 12, 'B-TYPE'), (13, 19, 'I-TYPE')]
#   Восстановлено:    [(0, 19, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'ножей кухонн'
#   Эталон (без 'O'): [(0, 5, 'B-TYPE'), (6, 12, 'I-TYPE')]
#   Восстановлено:    [(0, 12, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'супер контик'
#   Эталон (без 'O'): [(0, 5, 'B-BRAND'), (6, 12, 'I-BRAND')]
#   Восстановлено:    [(0, 12, 'B-BRAND')]
#   (Промежуточные BIO-теги: ['B-BRAND', 'I-BRAND', 'I-BRAND'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'сырок первый'
#   Эталон (без 'O'): [(0, 5, 'B-TYPE'), (6, 12, 'I-TYPE')]
#   Восстановлено:    [(0, 12, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'колбаса полукопченая'
#   Эталон (без 'O'): [(0, 7, 'B-TYPE'), (8, 20, 'I-TYPE')]
#   Восстановлено:    [(0, 20, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'крабовые палки'
#   Эталон (без 'O'): [(0, 8, 'B-TYPE'), (9, 14, 'I-TYPE')]
#   Восстановлено:    [(0, 14, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'овощи смесь'
#   Эталон (без 'O'): [(0, 5, 'B-TYPE'), (6, 11, 'I-TYPE')]
#   Восстановлено:    [(0, 11, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'сэльди слабосоленое'
#   Эталон (без 'O'): [(0, 6, 'B-TYPE'), (7, 19, 'I-TYPE')]
#   Восстановлено:    [(0, 19, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'печенье сладкая слобода'
#   Эталон (без 'O'): [(0, 7, 'B-TYPE'), (8, 15, 'B-BRAND'), (16, 23, 'I-BRAND')]
#   Восстановлено:    [(0, 7, 'B-TYPE'), (8, 23, 'B-BRAND')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'B-BRAND', 'I-BRAND', 'I-BRAND', 'I-BRAND'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'сырокопченые колбас'
#   Эталон (без 'O'): [(0, 12, 'B-TYPE'), (13, 19, 'I-TYPE')]
#   Восстановлено:    [(0, 19, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'сыр плавлен'
#   Эталон (без 'O'): [(0, 3, 'B-TYPE'), (4, 11, 'I-TYPE')]
#   Восстановлено:    [(0, 11, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'сыр моцарела'
#   Эталон (без 'O'): [(0, 3, 'B-TYPE'), (4, 12, 'I-TYPE')]
#   Восстановлено:    [(0, 12, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'сыр адыге'
#   Эталон (без 'O'): [(0, 3, 'B-TYPE'), (4, 9, 'I-TYPE')]
#   Восстановлено:    [(0, 9, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'соковая продукц'
#   Эталон (без 'O'): [(0, 7, 'B-TYPE'), (8, 15, 'I-TYPE')]
#   Восстановлено:    [(0, 15, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'мягкие вафли'
#   Эталон (без 'O'): [(0, 6, 'B-TYPE'), (7, 12, 'I-TYPE')]
#   Восстановлено:    [(0, 12, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'колбаса окраина брауншвейгская'
#   Эталон (без 'O'): [(0, 7, 'B-TYPE'), (8, 15, 'B-BRAND'), (16, 30, 'I-BRAND')]
#   Восстановлено:    [(0, 7, 'B-TYPE'), (8, 30, 'B-BRAND')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'B-BRAND', 'I-BRAND', 'I-BRAND', 'I-BRAND', 'I-BRAND', 'I-BRAND', 'I-BRAND', 'I-BRAND', 'I-BRAND'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'пивные напитки'
#   Эталон (без 'O'): [(0, 6, 'B-TYPE'), (7, 14, 'I-TYPE')]
#   Восстановлено:    [(0, 14, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'тушка куриная'
#   Эталон (без 'O'): [(0, 5, 'B-TYPE'), (6, 13, 'I-TYPE')]
#   Восстановлено:    [(0, 13, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'крабовые палочки за э'
#   Эталон (без 'O'): [(0, 8, 'B-TYPE'), (9, 16, 'I-TYPE')]
#   Восстановлено:    [(0, 16, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'O', 'O'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'кроликов охлажденны'
#   Эталон (без 'O'): [(0, 8, 'B-TYPE'), (9, 19, 'I-TYPE')]
#   Восстановлено:    [(0, 19, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'набор конфетный'
#   Эталон (без 'O'): [(0, 5, 'B-TYPE'), (6, 15, 'I-TYPE')]
#   Восстановлено:    [(0, 15, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'колбаса мясная'
#   Эталон (без 'O'): [(0, 7, 'B-TYPE'), (8, 14, 'I-TYPE')]
#   Восстановлено:    [(0, 14, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'крем творожный'
#   Эталон (без 'O'): [(0, 4, 'B-TYPE'), (5, 14, 'I-TYPE')]
#   Восстановлено:    [(0, 14, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'йогурт био'
#   Эталон (без 'O'): [(0, 6, 'B-TYPE'), (7, 10, 'I-TYPE')]
#   Восстановлено:    [(0, 10, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'смягчители во'
#   Эталон (без 'O'): [(0, 10, 'B-TYPE'), (11, 13, 'I-TYPE')]
#   Восстановлено:    [(0, 13, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'наборы электроник'
#   Эталон (без 'O'): [(0, 6, 'B-TYPE'), (7, 17, 'I-TYPE')]
#   Восстановлено:    [(0, 17, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'увлажнители воздух'
#   Эталон (без 'O'): [(0, 11, 'B-TYPE'), (12, 18, 'I-TYPE')]
#   Восстановлено:    [(0, 18, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'суфле творожное'
#   Эталон (без 'O'): [(0, 5, 'B-TYPE'), (6, 15, 'I-TYPE')]
#   Восстановлено:    [(0, 15, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'тыквенные семечки'
#   Эталон (без 'O'): [(0, 9, 'B-TYPE'), (10, 17, 'I-TYPE')]
#   Восстановлено:    [(0, 17, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'булочки с вареной'
#   Эталон (без 'O'): [(0, 7, 'B-TYPE'), (8, 9, 'I-TYPE'), (10, 17, 'I-TYPE')]
#   Восстановлено:    [(0, 17, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'молочный коктейль фруто'
#   Эталон (без 'O'): [(0, 8, 'B-TYPE'), (9, 17, 'I-TYPE'), (18, 23, 'B-BRAND')]
#   Восстановлено:    [(0, 17, 'B-TYPE'), (18, 23, 'B-BRAND')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'B-BRAND', 'I-BRAND', 'I-BRAND'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'масло сливочное вологодское'
#   Эталон (без 'O'): [(0, 5, 'B-TYPE'), (6, 15, 'I-TYPE'), (16, 27, 'B-BRAND')]
#   Восстановлено:    [(0, 15, 'B-TYPE'), (16, 27, 'B-BRAND')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'B-BRAND', 'I-BRAND', 'I-BRAND', 'I-BRAND'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'щётка зубная'
#   Эталон (без 'O'): [(0, 5, 'B-TYPE'), (6, 12, 'I-TYPE')]
#   Восстановлено:    [(0, 12, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'кисломолочные сме'
#   Эталон (без 'O'): [(0, 13, 'B-TYPE'), (14, 17, 'I-TYPE')]
#   Восстановлено:    [(0, 17, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'бумажно-целюлозная продукци'
#   Эталон (без 'O'): [(0, 18, 'B-TYPE'), (19, 27, 'I-TYPE')]
#   Восстановлено:    [(0, 27, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'сельди слабосолен'
#   Эталон (без 'O'): [(0, 6, 'B-TYPE'), (7, 17, 'I-TYPE')]
#   Восстановлено:    [(0, 17, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'карнавальные аксессуары'
#   Эталон (без 'O'): [(0, 12, 'B-TYPE'), (13, 23, 'I-TYPE')]
#   Восстановлено:    [(0, 23, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'колбаса нарезка с перцем'
#   Эталон (без 'O'): [(0, 7, 'B-TYPE'), (8, 15, 'I-TYPE')]
#   Восстановлено:    [(0, 15, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'O', 'O', 'O'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'сыр монастырский'
#   Эталон (без 'O'): [(0, 3, 'B-TYPE'), (4, 16, 'I-TYPE')]
#   Восстановлено:    [(0, 16, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'мясо охлажденное'
#   Эталон (без 'O'): [(0, 4, 'B-TYPE'), (5, 16, 'I-TYPE')]
#   Восстановлено:    [(0, 16, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'прочие тампон'
#   Эталон (без 'O'): [(0, 6, 'B-TYPE'), (7, 13, 'I-TYPE')]
#   Восстановлено:    [(0, 13, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'белое плодово'
#   Эталон (без 'O'): [(0, 5, 'B-TYPE'), (6, 13, 'I-TYPE')]
#   Восстановлено:    [(0, 13, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'бутылочки, поильник'
#   Эталон (без 'O'): [(0, 10, 'B-TYPE'), (11, 19, 'I-TYPE')]
#   Восстановлено:    [(0, 19, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'галоши защитны'
#   Эталон (без 'O'): [(0, 6, 'B-TYPE'), (7, 14, 'I-TYPE')]
#   Восстановлено:    [(0, 14, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'каша рисо'
#   Эталон (без 'O'): [(0, 4, 'B-TYPE'), (5, 9, 'I-TYPE')]
#   Восстановлено:    [(0, 9, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'водный спорт'
#   Эталон (без 'O'): [(0, 6, 'B-TYPE'), (7, 12, 'I-TYPE')]
#   Восстановлено:    [(0, 12, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'мешки 60 л'
#   Эталон (без 'O'): [(0, 5, 'B-TYPE'), (6, 8, 'B-VOLUME'), (9, 10, 'I-VOLUME')]
#   Восстановлено:    [(0, 5, 'B-TYPE'), (6, 10, 'B-VOLUME')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'B-VOLUME', 'I-VOLUME'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'лосьон чистая линия'
#   Эталон (без 'O'): [(0, 6, 'B-TYPE'), (7, 13, 'B-BRAND'), (14, 19, 'I-BRAND')]
#   Восстановлено:    [(0, 6, 'B-TYPE'), (7, 19, 'B-BRAND')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'B-BRAND', 'I-BRAND', 'I-BRAND'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'шоколад милки вей'
#   Эталон (без 'O'): [(0, 7, 'B-TYPE'), (8, 13, 'B-BRAND'), (14, 17, 'I-BRAND')]
#   Восстановлено:    [(0, 7, 'B-TYPE'), (8, 17, 'B-BRAND')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'B-BRAND', 'I-BRAND', 'I-BRAND', 'I-BRAND'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'макароны красная цена'
#   Эталон (без 'O'): [(0, 8, 'B-TYPE'), (9, 16, 'B-BRAND'), (17, 21, 'I-BRAND')]
#   Восстановлено:    [(0, 8, 'B-TYPE'), (9, 21, 'B-BRAND')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'B-BRAND', 'I-BRAND', 'I-BRAND'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'индейки ох'
#   Эталон (без 'O'): [(0, 7, 'B-TYPE'), (8, 10, 'I-TYPE')]
#   Восстановлено:    [(0, 10, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'мясные консерв'
#   Эталон (без 'O'): [(0, 6, 'B-TYPE'), (7, 14, 'I-TYPE')]
#   Восстановлено:    [(0, 14, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'перепелиное яйцо'
#   Эталон (без 'O'): [(0, 11, 'B-TYPE'), (12, 16, 'I-TYPE')]
#   Восстановлено:    [(0, 16, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'вина игристое'
#   Эталон (без 'O'): [(0, 4, 'B-TYPE'), (5, 13, 'I-TYPE')]
#   Восстановлено:    [(0, 13, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'торт наполеон'
#   Эталон (без 'O'): [(0, 4, 'B-TYPE'), (5, 13, 'I-TYPE')]
#   Восстановлено:    [(0, 13, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'пищевая сода'
#   Эталон (без 'O'): [(0, 7, 'B-TYPE'), (8, 12, 'I-TYPE')]
#   Восстановлено:    [(0, 12, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'белковая продукци'
#   Эталон (без 'O'): [(0, 8, 'B-TYPE'), (9, 17, 'I-TYPE')]
#   Восстановлено:    [(0, 17, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'тертые томаты'
#   Эталон (без 'O'): [(0, 6, 'B-TYPE'), (7, 13, 'I-TYPE')]
#   Восстановлено:    [(0, 13, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'творог зерненый савушкин'
#   Эталон (без 'O'): [(0, 6, 'B-TYPE'), (7, 15, 'I-TYPE'), (16, 24, 'B-BRAND')]
#   Восстановлено:    [(0, 15, 'B-TYPE'), (16, 24, 'B-BRAND')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'B-BRAND', 'I-BRAND', 'I-BRAND'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'рис шлифованный'
#   Эталон (без 'O'): [(0, 3, 'B-TYPE'), (4, 15, 'I-TYPE')]
#   Восстановлено:    [(0, 15, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'станция молочная'
#   Эталон (без 'O'): [(0, 7, 'B-TYPE'), (8, 16, 'I-TYPE')]
#   Восстановлено:    [(0, 16, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'йогурт три кота'
#   Эталон (без 'O'): [(0, 6, 'B-TYPE'), (7, 10, 'B-BRAND'), (11, 15, 'I-BRAND')]
#   Восстановлено:    [(0, 6, 'B-TYPE'), (7, 15, 'B-BRAND')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'B-BRAND', 'I-BRAND', 'I-BRAND'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'масло бежин луг'
#   Эталон (без 'O'): [(0, 5, 'B-TYPE'), (6, 11, 'B-BRAND'), (12, 15, 'I-BRAND')]
#   Восстановлено:    [(0, 5, 'B-TYPE'), (6, 15, 'B-BRAND')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'B-BRAND', 'I-BRAND', 'I-BRAND', 'I-BRAND'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'молоко молочная станция'
#   Эталон (без 'O'): [(0, 6, 'B-TYPE'), (7, 15, 'B-BRAND'), (16, 23, 'I-BRAND')]
#   Восстановлено:    [(0, 6, 'B-TYPE'), (7, 23, 'B-BRAND')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'B-BRAND', 'I-BRAND', 'I-BRAND', 'I-BRAND'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'сырный проду'
#   Эталон (без 'O'): [(0, 6, 'B-TYPE'), (7, 12, 'I-TYPE')]
#   Восстановлено:    [(0, 12, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'вода газировпнная красная цена'
#   Эталон (без 'O'): [(0, 4, 'B-TYPE'), (5, 17, 'I-TYPE')]
#   Восстановлено:    [(0, 17, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'O', 'O', 'O'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'смешанный р'
#   Эталон (без 'O'): [(0, 9, 'B-TYPE'), (10, 11, 'I-TYPE')]
#   Восстановлено:    [(0, 11, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'курица бедро'
#   Эталон (без 'O'): [(0, 6, 'B-TYPE'), (7, 12, 'I-TYPE')]
#   Восстановлено:    [(0, 12, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'стиральный  порошок'
#   Эталон (без 'O'): [(0, 10, 'B-TYPE'), (12, 19, 'I-TYPE')]
#   Восстановлено:    [(0, 19, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'колбаса докторская вязанка'
#   Эталон (без 'O'): [(0, 7, 'B-TYPE'), (8, 18, 'I-TYPE'), (19, 26, 'B-BRAND')]
#   Восстановлено:    [(0, 18, 'B-TYPE'), (19, 26, 'B-BRAND')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'B-BRAND', 'I-BRAND', 'I-BRAND'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'кисломолочные смеси'
#   Эталон (без 'O'): [(0, 13, 'B-TYPE'), (14, 19, 'I-TYPE')]
#   Восстановлено:    [(0, 19, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'кефир обезжиренный'
#   Эталон (без 'O'): [(0, 5, 'B-TYPE'), (6, 18, 'I-TYPE')]
#   Восстановлено:    [(0, 18, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'гречневая каша'
#   Эталон (без 'O'): [(0, 9, 'B-TYPE'), (10, 14, 'I-TYPE')]
#   Восстановлено:    [(0, 14, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'кабачок пюре'
#   Эталон (без 'O'): [(0, 7, 'B-TYPE'), (8, 12, 'I-TYPE')]
#   Восстановлено:    [(0, 12, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'пакеты 60 л'
#   Эталон (без 'O'): [(0, 6, 'B-TYPE'), (7, 9, 'B-VOLUME'), (10, 11, 'I-VOLUME')]
#   Восстановлено:    [(0, 6, 'B-TYPE'), (7, 11, 'B-VOLUME')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'B-VOLUME', 'I-VOLUME'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'сыр рассольны'
#   Эталон (без 'O'): [(0, 3, 'B-TYPE'), (4, 13, 'I-TYPE')]
#   Восстановлено:    [(0, 13, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'сыр твороженный'
#   Эталон (без 'O'): [(0, 3, 'B-TYPE'), (4, 15, 'I-TYPE')]
#   Восстановлено:    [(0, 15, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'уксусная кислота'
#   Эталон (без 'O'): [(0, 8, 'B-TYPE'), (9, 16, 'I-TYPE')]
#   Восстановлено:    [(0, 16, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'мясной хлебец'
#   Эталон (без 'O'): [(0, 6, 'B-TYPE'), (7, 13, 'I-TYPE')]
#   Восстановлено:    [(0, 13, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'томаты коктейльные'
#   Эталон (без 'O'): [(0, 6, 'B-TYPE'), (7, 18, 'I-TYPE')]
#   Восстановлено:    [(0, 18, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'сыр топленочка'
#   Эталон (без 'O'): [(0, 3, 'B-TYPE'), (4, 14, 'I-TYPE')]
#   Восстановлено:    [(0, 14, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'мука кукурузн'
#   Эталон (без 'O'): [(0, 4, 'B-TYPE'), (5, 13, 'I-TYPE')]
#   Восстановлено:    [(0, 13, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'питьевой йогурт в мягкой'
#   Эталон (без 'O'): [(0, 8, 'B-TYPE'), (9, 15, 'I-TYPE')]
#   Восстановлено:    [(0, 15, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'O', 'O', 'O'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'полуфабрикаты хлебобулочн'
#   Эталон (без 'O'): [(0, 13, 'B-TYPE'), (14, 25, 'I-TYPE')]
#   Восстановлено:    [(0, 25, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'суп грибной'
#   Эталон (без 'O'): [(0, 3, 'B-TYPE'), (4, 11, 'I-TYPE')]
#   Восстановлено:    [(0, 11, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'радиоуправляемые игр'
#   Эталон (без 'O'): [(0, 16, 'B-TYPE'), (17, 20, 'I-TYPE')]
#   Восстановлено:    [(0, 20, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'чай черный крупно'
#   Эталон (без 'O'): [(0, 3, 'B-TYPE'), (4, 10, 'I-TYPE')]
#   Восстановлено:    [(0, 10, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'O', 'O'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'лимонад тархун'
#   Эталон (без 'O'): [(0, 7, 'B-TYPE'), (8, 14, 'I-TYPE')]
#   Восстановлено:    [(0, 14, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'сельдь замороженная'
#   Эталон (без 'O'): [(0, 6, 'B-TYPE'), (7, 19, 'I-TYPE')]
#   Восстановлено:    [(0, 19, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'фены технически'
#   Эталон (без 'O'): [(0, 4, 'B-TYPE'), (5, 15, 'I-TYPE')]
#   Восстановлено:    [(0, 15, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'галантерейные аксессуа'
#   Эталон (без 'O'): [(0, 13, 'B-TYPE'), (14, 22, 'I-TYPE')]
#   Восстановлено:    [(0, 22, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'белое виноградное'
#   Эталон (без 'O'): [(0, 5, 'B-TYPE'), (6, 17, 'I-TYPE')]
#   Восстановлено:    [(0, 17, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'чай краснодарский'
#   Эталон (без 'O'): [(0, 3, 'B-TYPE'), (4, 17, 'I-TYPE')]
#   Восстановлено:    [(0, 17, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'черный рис'
#   Эталон (без 'O'): [(0, 6, 'B-TYPE'), (7, 10, 'I-TYPE')]
#   Восстановлено:    [(0, 10, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'шоколадный коктейль'
#   Эталон (без 'O'): [(0, 10, 'B-TYPE'), (11, 19, 'I-TYPE')]
#   Восстановлено:    [(0, 19, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'гель магия черного'
#   Эталон (без 'O'): [(0, 4, 'B-TYPE'), (5, 10, 'B-BRAND'), (11, 18, 'I-BRAND')]
#   Восстановлено:    [(0, 4, 'B-TYPE'), (5, 18, 'B-BRAND')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'B-BRAND', 'I-BRAND', 'I-BRAND', 'I-BRAND'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'палатки, доми'
#   Эталон (без 'O'): [(0, 8, 'B-TYPE'), (9, 13, 'I-TYPE')]
#   Восстановлено:    [(0, 13, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# ...
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'садовый дек'
#   Эталон (без 'O'): [(0, 7, 'B-TYPE'), (8, 11, 'I-TYPE')]
#   Восстановлено:    [(0, 11, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'смесь овощно'
#   Эталон (без 'O'): [(0, 5, 'B-TYPE'), (6, 12, 'I-TYPE')]
#   Восстановлено:    [(0, 12, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'вареники сытый папа'
#   Эталон (без 'O'): [(0, 8, 'B-TYPE'), (9, 14, 'B-BRAND'), (15, 19, 'I-BRAND')]
#   Восстановлено:    [(0, 8, 'B-TYPE'), (9, 19, 'B-BRAND')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'B-BRAND', 'I-BRAND', 'I-BRAND', 'I-BRAND'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'джем клубничный'
#   Эталон (без 'O'): [(0, 4, 'B-TYPE'), (5, 15, 'I-TYPE')]
#   Восстановлено:    [(0, 15, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'крупа гречнева'
#   Эталон (без 'O'): [(0, 5, 'B-TYPE'), (6, 14, 'I-TYPE')]
#   Восстановлено:    [(0, 14, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'яичная лапша'
#   Эталон (без 'O'): [(0, 6, 'B-TYPE'), (7, 12, 'I-TYPE')]
#   Восстановлено:    [(0, 12, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'грудка копченая'
#   Эталон (без 'O'): [(0, 6, 'B-TYPE'), (7, 15, 'I-TYPE')]
#   Восстановлено:    [(0, 15, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'чай черный 25'
#   Эталон (без 'O'): [(0, 3, 'B-TYPE'), (4, 10, 'I-TYPE'), (11, 13, 'B-VOLUME')]
#   Восстановлено:    [(0, 10, 'B-TYPE'), (11, 13, 'B-VOLUME')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'B-VOLUME'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'детский творожок'
#   Эталон (без 'O'): [(0, 7, 'B-TYPE'), (8, 16, 'I-TYPE')]
#   Восстановлено:    [(0, 16, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'молочным коктейл'
#   Эталон (без 'O'): [(0, 8, 'B-TYPE'), (9, 16, 'I-TYPE')]
#   Восстановлено:    [(0, 16, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'селедка матиас'
#   Эталон (без 'O'): [(0, 7, 'B-TYPE'), (8, 14, 'I-TYPE')]
#   Восстановлено:    [(0, 14, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'напиток кофейный'
#   Эталон (без 'O'): [(0, 7, 'B-TYPE'), (8, 16, 'I-TYPE')]
#   Восстановлено:    [(0, 16, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'повседневная одежда'
#   Эталон (без 'O'): [(0, 12, 'B-TYPE'), (13, 19, 'I-TYPE')]
#   Восстановлено:    [(0, 19, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'яйцо перепело'
#   Эталон (без 'O'): [(0, 4, 'B-TYPE'), (5, 13, 'I-TYPE')]
#   Восстановлено:    [(0, 13, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'кофе растворимы'
#   Эталон (без 'O'): [(0, 4, 'B-TYPE'), (5, 15, 'I-TYPE')]
#   Восстановлено:    [(0, 15, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'шоколад рита спорт'
#   Эталон (без 'O'): [(0, 7, 'B-TYPE'), (8, 12, 'B-BRAND'), (13, 18, 'I-BRAND')]
#   Восстановлено:    [(0, 7, 'B-TYPE'), (8, 18, 'B-BRAND')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'B-BRAND', 'I-BRAND', 'I-BRAND'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'вареная колбаса'
#   Эталон (без 'O'): [(0, 7, 'B-TYPE'), (8, 15, 'I-TYPE')]
#   Восстановлено:    [(0, 15, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'чай черный байховый'
#   Эталон (без 'O'): [(0, 3, 'B-TYPE'), (4, 10, 'I-TYPE'), (11, 19, 'I-TYPE')]
#   Восстановлено:    [(0, 19, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'варенье абрикосовое'
#   Эталон (без 'O'): [(0, 7, 'B-TYPE'), (8, 19, 'I-TYPE')]
#   Восстановлено:    [(0, 19, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'набор чайный'
#   Эталон (без 'O'): [(0, 5, 'B-TYPE'), (6, 12, 'I-TYPE')]
#   Восстановлено:    [(0, 12, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'фруто няня яблоко'
#   Эталон (без 'O'): [(0, 5, 'B-BRAND'), (6, 10, 'I-BRAND'), (11, 17, 'B-TYPE')]
#   Восстановлено:    [(0, 10, 'B-BRAND'), (11, 17, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-BRAND', 'I-BRAND', 'I-BRAND', 'I-BRAND', 'I-BRAND', 'B-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'печенье рыбки'
#   Эталон (без 'O'): [(0, 7, 'B-TYPE'), (8, 13, 'I-TYPE')]
#   Восстановлено:    [(0, 13, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'майонез лёгкий'
#   Эталон (без 'O'): [(0, 7, 'B-TYPE'), (8, 14, 'I-TYPE')]
#   Восстановлено:    [(0, 14, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'рис пропа'
#   Эталон (без 'O'): [(0, 3, 'B-TYPE'), (4, 9, 'I-TYPE')]
#   Восстановлено:    [(0, 9, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'манная кру'
#   Эталон (без 'O'): [(0, 6, 'B-TYPE'), (7, 10, 'I-TYPE')]
#   Восстановлено:    [(0, 10, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'настольные коври'
#   Эталон (без 'O'): [(0, 10, 'B-TYPE'), (11, 16, 'I-TYPE')]
#   Восстановлено:    [(0, 16, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'лук шалот'
#   Эталон (без 'O'): [(0, 3, 'B-TYPE'), (4, 9, 'I-TYPE')]
#   Восстановлено:    [(0, 9, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'цельнозерновой хлеб'
#   Эталон (без 'O'): [(0, 14, 'B-TYPE'), (15, 19, 'I-TYPE')]
#   Восстановлено:    [(0, 19, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'печенье русский хлеб'
#   Эталон (без 'O'): [(0, 7, 'B-TYPE'), (8, 15, 'B-BRAND'), (16, 20, 'I-BRAND')]
#   Восстановлено:    [(0, 7, 'B-TYPE'), (8, 20, 'B-BRAND')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'B-BRAND', 'I-BRAND'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'яйцо шоко'
#   Эталон (без 'O'): [(0, 4, 'B-TYPE'), (5, 9, 'I-TYPE')]
#   Восстановлено:    [(0, 9, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'рыба мас'
#   Эталон (без 'O'): [(0, 4, 'B-TYPE'), (5, 8, 'I-TYPE')]
#   Восстановлено:    [(0, 8, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'кефир детский агуша'
#   Эталон (без 'O'): [(0, 5, 'B-TYPE'), (6, 13, 'I-TYPE'), (14, 19, 'B-BRAND')]
#   Восстановлено:    [(0, 13, 'B-TYPE'), (14, 19, 'B-BRAND')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'B-BRAND', 'I-BRAND'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'хлебные палоч'
#   Эталон (без 'O'): [(0, 7, 'B-TYPE'), (8, 13, 'I-TYPE')]
#   Восстановлено:    [(0, 13, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'масло эко'
#   Эталон (без 'O'): [(0, 5, 'B-TYPE'), (6, 9, 'I-TYPE')]
#   Восстановлено:    [(0, 9, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'чай бабушкино лу'
#   Эталон (без 'O'): [(0, 3, 'B-TYPE'), (4, 13, 'B-BRAND'), (14, 16, 'I-BRAND')]
#   Восстановлено:    [(0, 3, 'B-TYPE'), (4, 16, 'B-BRAND')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'B-BRAND', 'I-BRAND', 'I-BRAND', 'I-BRAND'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'хлеб боро'
#   Эталон (без 'O'): [(0, 4, 'B-TYPE'), (5, 9, 'I-TYPE')]
#   Восстановлено:    [(0, 9, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'грибы вешенки'
#   Эталон (без 'O'): [(0, 5, 'B-TYPE'), (6, 13, 'I-TYPE')]
#   Восстановлено:    [(0, 13, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'сыр копченая'
#   Эталон (без 'O'): [(0, 3, 'B-TYPE'), (4, 12, 'I-TYPE')]
#   Восстановлено:    [(0, 12, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'приправа бульон'
#   Эталон (без 'O'): [(0, 8, 'B-TYPE'), (9, 15, 'I-TYPE')]
#   Восстановлено:    [(0, 15, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ОБНАРУЖЕНО РАСХОЖДЕНИЕ В ПРИМЕРЕ: 'корм жидк'
#   Эталон (без 'O'): [(0, 4, 'B-TYPE'), (5, 9, 'I-TYPE')]
#   Восстановлено:    [(0, 9, 'B-TYPE')]
#   (Промежуточные BIO-теги: ['B-TYPE', 'I-TYPE', 'I-TYPE', 'I-TYPE'])
# --------------------------------------------------------------------------------
#
# ========================================
# РЕЗУЛЬТАТ: ПРОВАЛ. Обнаружено 196 ошибок на 1000 примерах.
# ========================================
